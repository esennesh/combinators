# %%
# %cd ..

# %%
import discopy.cartesian as cartesian
from discopy.rigid import PRO, Ty

from combinators import lens, sampler, tracing, utils
from combinators.model import collections

# %%
iid0 = collections.iid(0, 0)

# %%
iid0.draw()

# %%
iid1 = collections.iid(lens.LensTy.named('x'), 1)

# %%
iid1.draw()

# %%
iid2 = collections.iid(lens.LensTy.named('x'), 2)

# %%
iid2.draw()

# %%
iid3 = collections.iid(1, 3)

# %%
iid3.draw()

# %%
iid4 = collections.iid(1, 4)

# %%
iid4.draw()

# %%
iid22 = collections.iid(lens.LensTy.named('x', 'y'), 2)

# %%
iid22.draw()

# %%
iid32 = collections.iid(lens.LensTy.named('x', 'y', 'z'), 2)

# %%
iid32.draw()

# %%
iid33 = collections.iid(lens.LensTy.named('x', 'y', 'z'), 3, lens.Id(lens.LensTy.named('x', 'y', 'z')))

# %%
iid33.draw()

# %%
iid33(1, 2, 3)
# Out:
# ((1, 2, 3, 1, 2, 3, 1, 2, 3), (0.0, Trace{}))

# %%
iid33.__class__
# Out:
# combinators.tracing.TracedLensDiagram

# %%
iid12 = collections.iid(1, 2, lens.Id(lens.LensPRO(1)))

# %%
iid12swap = iid12 >> lens.SWAP

# %%
iid12swap.draw()

# %%
unitiid12swap = lens.Unit(1, lens.LensPRO(1)) >> iid12swap

# %%
unitiid12swap()
# Out:
# ((0.0, Trace{}), (1, 1))
